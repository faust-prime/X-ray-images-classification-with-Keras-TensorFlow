# %%
from keras.models import Model
from keras.applications.nasnet import NASNetMobile
model = NASNetMobile(include_top=True, weights='imagenet')
model.compile(optimizer='rmsprop', loss='categorical_crossentropy')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# stem_conv1 (Conv2D)             (None, 111, 111, 32) 864         input_2[0][0]
# __________________________________________________________________________________________________
# stem_bn1 (BatchNormalization)   (None, 111, 111, 32) 128         stem_conv1[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 111, 111, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_1 (Conv2D (None, 111, 111, 11) 352         activation_189[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_1 (BatchNor (None, 111, 111, 11) 44          reduction_conv_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 111, 111, 11) 0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 111, 111, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 115, 115, 11) 0           activation_190[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 117, 117, 32) 0           activation_192[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 56, 56, 11)   396         separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 56, 56, 11)   1920        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 56, 56, 11)   44          separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 56, 56, 11)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_193 (Activation)     (None, 56, 56, 11)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 56, 56, 11)   396         activation_191[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 56, 56, 11)   660         activation_193[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, 111, 111, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 56, 56, 11)   44          separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 117, 117, 32) 0           activation_194[0][0]
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, 111, 111, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_1 (Add)    (None, 56, 56, 11)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 56, 56, 11)   1920        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 115, 115, 32) 0           activation_196[0][0]
# __________________________________________________________________________________________________
# activation_198 (Activation)     (None, 56, 56, 11)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 56, 56, 11)   1152        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 56, 56, 11)   220         activation_198[0][0]
# __________________________________________________________________________________________________
# activation_195 (Activation)     (None, 56, 56, 11)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 56, 56, 11)   44          separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_1 (ZeroPad (None, 113, 113, 11) 0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 56, 56, 11)   660         activation_195[0][0]
# __________________________________________________________________________________________________
# activation_197 (Activation)     (None, 56, 56, 11)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_199 (Activation)     (None, 56, 56, 11)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_1 (MaxPool (None, 56, 56, 11)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 56, 56, 11)   396         activation_197[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 56, 56, 11)   220         activation_199[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_stem_2 (Activatio (None, 111, 111, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_1 (Add)    (None, 56, 56, 11)   0           reduction_left2_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_1 (Average (None, 56, 56, 11)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_1 (Average (None, 56, 56, 11)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 56, 56, 11)   44          separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_1 (MaxPoo (None, 56, 56, 11)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 112, 112, 32) 0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_1 (Add)     (None, 56, 56, 11)   0           reduction_left3_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 56, 56, 11)   0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_left4_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_1 (Add)     (None, 56, 56, 11)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_1[0][0]
# __________________________________________________________________________________________________
# cropping2d_5 (Cropping2D)       (None, 111, 111, 32) 0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_1 (Concat (None, 56, 56, 44)   0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_add3_stem_1[0][0]
#                                                                  add_5[0][0]
#                                                                  reduction_add4_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_stem_2 (Avera (None, 56, 56, 32)   0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_stem_2 (Avera (None, 56, 56, 32)   0           cropping2d_5[0][0]
# __________________________________________________________________________________________________
# activation_200 (Activation)     (None, 56, 56, 44)   0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_stem_2 (Conv2D)   (None, 56, 56, 11)   352         adjust_avg_pool_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_stem_2 (Conv2D)   (None, 56, 56, 11)   352         adjust_avg_pool_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_2 (Conv2D (None, 56, 56, 22)   968         activation_200[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 56, 56, 22)   0           adjust_conv_1_stem_2[0][0]
#                                                                  adjust_conv_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_2 (BatchNor (None, 56, 56, 22)   88          reduction_conv_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_bn_stem_2 (BatchNormaliz (None, 56, 56, 22)   88          concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_201 (Activation)     (None, 56, 56, 22)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_203 (Activation)     (None, 56, 56, 22)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 59, 59, 22)   0           activation_201[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 61, 61, 22)   0           activation_203[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 28, 28, 22)   1034        separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 28, 28, 22)   1562        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 28, 28, 22)   88          separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_202 (Activation)     (None, 28, 28, 22)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_204 (Activation)     (None, 28, 28, 22)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 28, 28, 22)   1034        activation_202[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 28, 28, 22)   1562        activation_204[0][0]
# __________________________________________________________________________________________________
# activation_205 (Activation)     (None, 56, 56, 22)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 28, 28, 22)   88          separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 61, 61, 22)   0           activation_205[0][0]
# __________________________________________________________________________________________________
# activation_207 (Activation)     (None, 56, 56, 22)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_2 (Add)    (None, 28, 28, 22)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 28, 28, 22)   1562        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 59, 59, 22)   0           activation_207[0][0]
# __________________________________________________________________________________________________
# activation_209 (Activation)     (None, 28, 28, 22)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 28, 28, 22)   1034        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 28, 28, 22)   682         activation_209[0][0]
# __________________________________________________________________________________________________
# activation_206 (Activation)     (None, 28, 28, 22)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 28, 28, 22)   88          separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_2 (ZeroPad (None, 57, 57, 22)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 28, 28, 22)   1562        activation_206[0][0]
# __________________________________________________________________________________________________
# activation_208 (Activation)     (None, 28, 28, 22)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_210 (Activation)     (None, 28, 28, 22)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_2 (MaxPool (None, 28, 28, 22)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 28, 28, 22)   1034        activation_208[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 28, 28, 22)   682         activation_210[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_0 (Activation)    (None, 56, 56, 44)   0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_2 (Add)    (None, 28, 28, 22)   0           reduction_left2_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_2 (Average (None, 28, 28, 22)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_2 (Average (None, 28, 28, 22)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 28, 28, 22)   88          separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_2 (MaxPoo (None, 28, 28, 22)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 57, 57, 44)   0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_2 (Add)     (None, 28, 28, 22)   0           reduction_left3_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 28, 28, 22)   0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_left4_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_2 (Add)     (None, 28, 28, 22)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_2[0][0]
# __________________________________________________________________________________________________
# cropping2d_6 (Cropping2D)       (None, 56, 56, 44)   0           zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_2 (Concat (None, 28, 28, 88)   0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_add3_stem_2[0][0]
#                                                                  add_6[0][0]
#                                                                  reduction_add4_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_0 (AveragePoo (None, 28, 28, 44)   0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_0 (AveragePoo (None, 28, 28, 44)   0           cropping2d_6[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_0 (Conv2D)        (None, 28, 28, 22)   968         adjust_avg_pool_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_0 (Conv2D)        (None, 28, 28, 22)   968         adjust_avg_pool_2_0[0][0]
# __________________________________________________________________________________________________
# activation_211 (Activation)     (None, 28, 28, 88)   0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 28, 28, 44)   0           adjust_conv_1_0[0][0]
#                                                                  adjust_conv_2_0[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_0 (Conv2D)        (None, 28, 28, 44)   3872        activation_211[0][0]
# __________________________________________________________________________________________________
# adjust_bn_0 (BatchNormalization (None, 28, 28, 44)   176         concatenate_6[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_0 (BatchNormalizati (None, 28, 28, 44)   176         normal_conv_1_0[0][0]
# __________________________________________________________________________________________________
# activation_212 (Activation)     (None, 28, 28, 44)   0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# activation_214 (Activation)     (None, 28, 28, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_216 (Activation)     (None, 28, 28, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_218 (Activation)     (None, 28, 28, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_220 (Activation)     (None, 28, 28, 44)   0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_0 (None, 28, 28, 44)   3036        activation_212[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 28, 28, 44)   2332        activation_214[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_0 (None, 28, 28, 44)   3036        activation_216[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 28, 28, 44)   2332        activation_218[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_0 (None, 28, 28, 44)   2332        activation_220[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left1_0[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_1_normal_right1_0[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left2_0[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_1_normal_right2_0[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left5_0[0
# __________________________________________________________________________________________________
# activation_213 (Activation)     (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_215 (Activation)     (None, 28, 28, 44)   0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_217 (Activation)     (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_219 (Activation)     (None, 28, 28, 44)   0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_221 (Activation)     (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_0 (None, 28, 28, 44)   3036        activation_213[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 28, 28, 44)   2332        activation_215[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_0 (None, 28, 28, 44)   3036        activation_217[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 28, 28, 44)   2332        activation_219[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_0 (None, 28, 28, 44)   2332        activation_221[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left1_0[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_2_normal_right1_0[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left2_0[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_2_normal_right2_0[
# __________________________________________________________________________________________________
# normal_left3_0 (AveragePooling2 (None, 28, 28, 44)   0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# normal_left4_0 (AveragePooling2 (None, 28, 28, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# normal_right4_0 (AveragePooling (None, 28, 28, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left5_0[0
# __________________________________________________________________________________________________
# normal_add_1_0 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_0 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_0 (Add)            (None, 28, 28, 44)   0           normal_left3_0[0][0]
#                                                                  adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# normal_add_4_0 (Add)            (None, 28, 28, 44)   0           normal_left4_0[0][0]
#                                                                  normal_right4_0[0][0]
# __________________________________________________________________________________________________
# normal_add_5_0 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# normal_concat_0 (Concatenate)   (None, 28, 28, 264)  0           adjust_bn_0[0][0]
#                                                                  normal_add_1_0[0][0]
#                                                                  normal_add_2_0[0][0]
#                                                                  normal_add_3_0[0][0]
#                                                                  normal_add_4_0[0][0]
#                                                                  normal_add_5_0[0][0]
# __________________________________________________________________________________________________
# activation_222 (Activation)     (None, 28, 28, 88)   0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_223 (Activation)     (None, 28, 28, 264)  0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_1 (Conv2 (None, 28, 28, 44)   3872        activation_222[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_1 (Conv2D)        (None, 28, 28, 44)   11616       activation_223[0][0]
# __________________________________________________________________________________________________
# adjust_bn_1 (BatchNormalization (None, 28, 28, 44)   176         adjust_conv_projection_1[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_1 (BatchNormalizati (None, 28, 28, 44)   176         normal_conv_1_1[0][0]
# __________________________________________________________________________________________________
# activation_224 (Activation)     (None, 28, 28, 44)   0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# activation_226 (Activation)     (None, 28, 28, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_228 (Activation)     (None, 28, 28, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_230 (Activation)     (None, 28, 28, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_232 (Activation)     (None, 28, 28, 44)   0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_1 (None, 28, 28, 44)   3036        activation_224[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 28, 28, 44)   2332        activation_226[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_1 (None, 28, 28, 44)   3036        activation_228[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 28, 28, 44)   2332        activation_230[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 28, 28, 44)   2332        activation_232[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_1_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_1_normal_right2_1[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left5_1[0
# __________________________________________________________________________________________________
# activation_225 (Activation)     (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_227 (Activation)     (None, 28, 28, 44)   0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_229 (Activation)     (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_231 (Activation)     (None, 28, 28, 44)   0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_233 (Activation)     (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 28, 28, 44)   3036        activation_225[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 28, 28, 44)   2332        activation_227[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 28, 28, 44)   3036        activation_229[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 28, 28, 44)   2332        activation_231[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 28, 28, 44)   2332        activation_233[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_2_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_2_normal_right2_1[
# __________________________________________________________________________________________________
# normal_left3_1 (AveragePooling2 (None, 28, 28, 44)   0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_left4_1 (AveragePooling2 (None, 28, 28, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_right4_1 (AveragePooling (None, 28, 28, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left5_1[0
# __________________________________________________________________________________________________
# normal_add_1_1 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_1 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_1 (Add)            (None, 28, 28, 44)   0           normal_left3_1[0][0]
#                                                                  adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_add_4_1 (Add)            (None, 28, 28, 44)   0           normal_left4_1[0][0]
#                                                                  normal_right4_1[0][0]
# __________________________________________________________________________________________________
# normal_add_5_1 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_concat_1 (Concatenate)   (None, 28, 28, 264)  0           adjust_bn_1[0][0]
#                                                                  normal_add_1_1[0][0]
#                                                                  normal_add_2_1[0][0]
#                                                                  normal_add_3_1[0][0]
#                                                                  normal_add_4_1[0][0]
#                                                                  normal_add_5_1[0][0]
# __________________________________________________________________________________________________
# activation_234 (Activation)     (None, 28, 28, 264)  0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# activation_235 (Activation)     (None, 28, 28, 264)  0           normal_concat_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_2 (Conv2 (None, 28, 28, 44)   11616       activation_234[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_2 (Conv2D)        (None, 28, 28, 44)   11616       activation_235[0][0]
# __________________________________________________________________________________________________
# adjust_bn_2 (BatchNormalization (None, 28, 28, 44)   176         adjust_conv_projection_2[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_2 (BatchNormalizati (None, 28, 28, 44)   176         normal_conv_1_2[0][0]
# __________________________________________________________________________________________________
# activation_236 (Activation)     (None, 28, 28, 44)   0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# activation_238 (Activation)     (None, 28, 28, 44)   0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_240 (Activation)     (None, 28, 28, 44)   0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_242 (Activation)     (None, 28, 28, 44)   0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_244 (Activation)     (None, 28, 28, 44)   0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_2 (None, 28, 28, 44)   3036        activation_236[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 28, 28, 44)   2332        activation_238[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_2 (None, 28, 28, 44)   3036        activation_240[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 28, 28, 44)   2332        activation_242[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_2 (None, 28, 28, 44)   2332        activation_244[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left1_2[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_1_normal_right1_2[
# ...
# __________________________________________________________________________________________________
# activation_361 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_363 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 7, 7, 176)    35376       activation_355[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 7, 7, 176)    32560       activation_357[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 7, 7, 176)    35376       activation_359[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 7, 7, 176)    32560       activation_361[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 7, 7, 176)    32560       activation_363[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left1_11[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_2_normal_right1_11
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left2_11[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_2_normal_right2_11
# __________________________________________________________________________________________________
# normal_left3_11 (AveragePooling (None, 7, 7, 176)    0           normal_bn_1_11[0][0]
# __________________________________________________________________________________________________
# normal_left4_11 (AveragePooling (None, 7, 7, 176)    0           adjust_bn_11[0][0]
# __________________________________________________________________________________________________
# normal_right4_11 (AveragePoolin (None, 7, 7, 176)    0           adjust_bn_11[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left5_11[
# __________________________________________________________________________________________________
# normal_add_1_11 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_11 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_11 (Add)           (None, 7, 7, 176)    0           normal_left3_11[0][0]
#                                                                  adjust_bn_11[0][0]
# __________________________________________________________________________________________________
# normal_add_4_11 (Add)           (None, 7, 7, 176)    0           normal_left4_11[0][0]
#                                                                  normal_right4_11[0][0]
# __________________________________________________________________________________________________
# normal_add_5_11 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_11[0][0]
# __________________________________________________________________________________________________
# normal_concat_11 (Concatenate)  (None, 7, 7, 1056)   0           adjust_bn_11[0][0]
#                                                                  normal_add_1_11[0][0]
#                                                                  normal_add_2_11[0][0]
#                                                                  normal_add_3_11[0][0]
#                                                                  normal_add_4_11[0][0]
#                                                                  normal_add_5_11[0][0]
# __________________________________________________________________________________________________
# activation_364 (Activation)     (None, 7, 7, 1056)   0           normal_concat_10[0][0]
# __________________________________________________________________________________________________
# activation_365 (Activation)     (None, 7, 7, 1056)   0           normal_concat_11[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_12 (Conv (None, 7, 7, 176)    185856      activation_364[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_12 (Conv2D)       (None, 7, 7, 176)    185856      activation_365[0][0]
# __________________________________________________________________________________________________
# adjust_bn_12 (BatchNormalizatio (None, 7, 7, 176)    704         adjust_conv_projection_12[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_12 (BatchNormalizat (None, 7, 7, 176)    704         normal_conv_1_12[0][0]
# __________________________________________________________________________________________________
# activation_366 (Activation)     (None, 7, 7, 176)    0           normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# activation_368 (Activation)     (None, 7, 7, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# activation_370 (Activation)     (None, 7, 7, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# activation_372 (Activation)     (None, 7, 7, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# activation_374 (Activation)     (None, 7, 7, 176)    0           normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_1 (None, 7, 7, 176)    35376       activation_366[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 7, 7, 176)    32560       activation_368[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_1 (None, 7, 7, 176)    35376       activation_370[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 7, 7, 176)    32560       activation_372[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 7, 7, 176)    32560       activation_374[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 7, 7, 176)    704         separable_conv_1_normal_left1_12[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_1_normal_right1_12
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 7, 7, 176)    704         separable_conv_1_normal_left2_12[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_1_normal_right2_12
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 7, 7, 176)    704         separable_conv_1_normal_left5_12[
# __________________________________________________________________________________________________
# activation_367 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_369 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_371 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_373 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_375 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 7, 7, 176)    35376       activation_367[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 7, 7, 176)    32560       activation_369[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 7, 7, 176)    35376       activation_371[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 7, 7, 176)    32560       activation_373[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 7, 7, 176)    32560       activation_375[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left1_12[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_2_normal_right1_12
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left2_12[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_2_normal_right2_12
# __________________________________________________________________________________________________
# normal_left3_12 (AveragePooling (None, 7, 7, 176)    0           normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# normal_left4_12 (AveragePooling (None, 7, 7, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# normal_right4_12 (AveragePoolin (None, 7, 7, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left5_12[
# __________________________________________________________________________________________________
# normal_add_1_12 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_12 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_12 (Add)           (None, 7, 7, 176)    0           normal_left3_12[0][0]
#                                                                  adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# normal_add_4_12 (Add)           (None, 7, 7, 176)    0           normal_left4_12[0][0]
#                                                                  normal_right4_12[0][0]
# __________________________________________________________________________________________________
# normal_add_5_12 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# normal_concat_12 (Concatenate)  (None, 7, 7, 1056)   0           adjust_bn_12[0][0]
#                                                                  normal_add_1_12[0][0]
#                                                                  normal_add_2_12[0][0]
#                                                                  normal_add_3_12[0][0]
#                                                                  normal_add_4_12[0][0]
#                                                                  normal_add_5_12[0][0]
# __________________________________________________________________________________________________
# activation_376 (Activation)     (None, 7, 7, 1056)   0           normal_concat_12[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 1056)         0           activation_376[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 1000)         1057000     global_average_pooling2d_2[0][0]
# ==================================================================================================
# Total params: 5,326,716
# Trainable params: 5,289,978
# Non-trainable params: 36,738
# __________________________________________________________________________________________________

# %%
for i, layer in enumerate(model.layers):
   print(i, layer.name)
# Out:
# 0 input_1
# 1 stem_conv1
# 2 stem_bn1
# 3 activation_1
# 4 reduction_conv_1_stem_1
# 5 reduction_bn_1_stem_1
# 6 activation_2
# 7 activation_4
# 8 separable_conv_1_pad_reduction_left1_stem_1
# 9 separable_conv_1_pad_reduction_right1_stem_1
# 10 separable_conv_1_reduction_left1_stem_1
# 11 separable_conv_1_reduction_right1_stem_1
# 12 separable_conv_1_bn_reduction_left1_stem_1
# 13 separable_conv_1_bn_reduction_right1_stem_1
# 14 activation_3
# 15 activation_5
# 16 separable_conv_2_reduction_left1_stem_1
# 17 separable_conv_2_reduction_right1_stem_1
# 18 activation_6
# 19 separable_conv_2_bn_reduction_left1_stem_1
# 20 separable_conv_2_bn_reduction_right1_stem_1
# 21 separable_conv_1_pad_reduction_right2_stem_1
# 22 activation_8
# 23 reduction_add_1_stem_1
# 24 separable_conv_1_reduction_right2_stem_1
# 25 separable_conv_1_pad_reduction_right3_stem_1
# 26 activation_10
# 27 separable_conv_1_bn_reduction_right2_stem_1
# 28 separable_conv_1_reduction_right3_stem_1
# 29 separable_conv_1_reduction_left4_stem_1
# 30 activation_7
# 31 separable_conv_1_bn_reduction_right3_stem_1
# 32 separable_conv_1_bn_reduction_left4_stem_1
# 33 reduction_pad_1_stem_1
# 34 separable_conv_2_reduction_right2_stem_1
# 35 activation_9
# 36 activation_11
# 37 reduction_left2_stem_1
# 38 separable_conv_2_bn_reduction_right2_stem_1
# 39 separable_conv_2_reduction_right3_stem_1
# 40 separable_conv_2_reduction_left4_stem_1
# 41 adjust_relu_1_stem_2
# 42 reduction_add_2_stem_1
# 43 reduction_left3_stem_1
# 44 separable_conv_2_bn_reduction_right3_stem_1
# 45 reduction_left4_stem_1
# 46 separable_conv_2_bn_reduction_left4_stem_1
# 47 reduction_right5_stem_1
# 48 zero_padding2d_1
# 49 reduction_add3_stem_1
# 50 add_1
# 51 reduction_add4_stem_1
# 52 cropping2d_1
# 53 reduction_concat_stem_1
# 54 adjust_avg_pool_1_stem_2
# 55 adjust_avg_pool_2_stem_2
# 56 activation_12
# 57 adjust_conv_1_stem_2
# 58 adjust_conv_2_stem_2
# 59 reduction_conv_1_stem_2
# 60 concatenate_1
# 61 reduction_bn_1_stem_2
# 62 adjust_bn_stem_2
# 63 activation_13
# 64 activation_15
# 65 separable_conv_1_pad_reduction_left1_stem_2
# 66 separable_conv_1_pad_reduction_right1_stem_2
# 67 separable_conv_1_reduction_left1_stem_2
# 68 separable_conv_1_reduction_right1_stem_2
# 69 separable_conv_1_bn_reduction_left1_stem_2
# 70 separable_conv_1_bn_reduction_right1_stem_2
# 71 activation_14
# 72 activation_16
# 73 separable_conv_2_reduction_left1_stem_2
# 74 separable_conv_2_reduction_right1_stem_2
# 75 activation_17
# 76 separable_conv_2_bn_reduction_left1_stem_2
# 77 separable_conv_2_bn_reduction_right1_stem_2
# 78 separable_conv_1_pad_reduction_right2_stem_2
# 79 activation_19
# 80 reduction_add_1_stem_2
# 81 separable_conv_1_reduction_right2_stem_2
# 82 separable_conv_1_pad_reduction_right3_stem_2
# 83 activation_21
# 84 separable_conv_1_bn_reduction_right2_stem_2
# 85 separable_conv_1_reduction_right3_stem_2
# 86 separable_conv_1_reduction_left4_stem_2
# 87 activation_18
# 88 separable_conv_1_bn_reduction_right3_stem_2
# 89 separable_conv_1_bn_reduction_left4_stem_2
# 90 reduction_pad_1_stem_2
# 91 separable_conv_2_reduction_right2_stem_2
# 92 activation_20
# 93 activation_22
# 94 reduction_left2_stem_2
# 95 separable_conv_2_bn_reduction_right2_stem_2
# 96 separable_conv_2_reduction_right3_stem_2
# 97 separable_conv_2_reduction_left4_stem_2
# 98 adjust_relu_1_0
# 99 reduction_add_2_stem_2
# 100 reduction_left3_stem_2
# 101 separable_conv_2_bn_reduction_right3_stem_2
# 102 reduction_left4_stem_2
# 103 separable_conv_2_bn_reduction_left4_stem_2
# 104 reduction_right5_stem_2
# 105 zero_padding2d_2
# 106 reduction_add3_stem_2
# 107 add_2
# 108 reduction_add4_stem_2
# 109 cropping2d_2
# 110 reduction_concat_stem_2
# 111 adjust_avg_pool_1_0
# 112 adjust_avg_pool_2_0
# 113 adjust_conv_1_0
# 114 adjust_conv_2_0
# 115 activation_23
# 116 concatenate_2
# 117 normal_conv_1_0
# 118 adjust_bn_0
# 119 normal_bn_1_0
# 120 activation_24
# 121 activation_26
# 122 activation_28
# 123 activation_30
# 124 activation_32
# 125 separable_conv_1_normal_left1_0
# 126 separable_conv_1_normal_right1_0
# 127 separable_conv_1_normal_left2_0
# 128 separable_conv_1_normal_right2_0
# 129 separable_conv_1_normal_left5_0
# 130 separable_conv_1_bn_normal_left1_0
# 131 separable_conv_1_bn_normal_right1_0
# 132 separable_conv_1_bn_normal_left2_0
# 133 separable_conv_1_bn_normal_right2_0
# 134 separable_conv_1_bn_normal_left5_0
# 135 activation_25
# 136 activation_27
# 137 activation_29
# 138 activation_31
# 139 activation_33
# 140 separable_conv_2_normal_left1_0
# 141 separable_conv_2_normal_right1_0
# 142 separable_conv_2_normal_left2_0
# 143 separable_conv_2_normal_right2_0
# 144 separable_conv_2_normal_left5_0
# 145 separable_conv_2_bn_normal_left1_0
# 146 separable_conv_2_bn_normal_right1_0
# 147 separable_conv_2_bn_normal_left2_0
# 148 separable_conv_2_bn_normal_right2_0
# 149 normal_left3_0
# 150 normal_left4_0
# 151 normal_right4_0
# 152 separable_conv_2_bn_normal_left5_0
# 153 normal_add_1_0
# 154 normal_add_2_0
# 155 normal_add_3_0
# 156 normal_add_4_0
# 157 normal_add_5_0
# 158 normal_concat_0
# 159 activation_34
# 160 activation_35
# 161 adjust_conv_projection_1
# 162 normal_conv_1_1
# 163 adjust_bn_1
# 164 normal_bn_1_1
# 165 activation_36
# 166 activation_38
# 167 activation_40
# 168 activation_42
# 169 activation_44
# 170 separable_conv_1_normal_left1_1
# 171 separable_conv_1_normal_right1_1
# 172 separable_conv_1_normal_left2_1
# 173 separable_conv_1_normal_right2_1
# 174 separable_conv_1_normal_left5_1
# 175 separable_conv_1_bn_normal_left1_1
# 176 separable_conv_1_bn_normal_right1_1
# 177 separable_conv_1_bn_normal_left2_1
# 178 separable_conv_1_bn_normal_right2_1
# 179 separable_conv_1_bn_normal_left5_1
# 180 activation_37
# 181 activation_39
# 182 activation_41
# 183 activation_43
# 184 activation_45
# 185 separable_conv_2_normal_left1_1
# 186 separable_conv_2_normal_right1_1
# 187 separable_conv_2_normal_left2_1
# 188 separable_conv_2_normal_right2_1
# 189 separable_conv_2_normal_left5_1
# 190 separable_conv_2_bn_normal_left1_1
# 191 separable_conv_2_bn_normal_right1_1
# 192 separable_conv_2_bn_normal_left2_1
# 193 separable_conv_2_bn_normal_right2_1
# 194 normal_left3_1
# 195 normal_left4_1
# 196 normal_right4_1
# 197 separable_conv_2_bn_normal_left5_1
# 198 normal_add_1_1
# 199 normal_add_2_1
# 200 normal_add_3_1
# 201 normal_add_4_1
# 202 normal_add_5_1
# 203 normal_concat_1
# 204 activation_46
# 205 activation_47
# 206 adjust_conv_projection_2
# 207 normal_conv_1_2
# 208 adjust_bn_2
# 209 normal_bn_1_2
# 210 activation_48
# 211 activation_50
# 212 activation_52
# 213 activation_54
# 214 activation_56
# 215 separable_conv_1_normal_left1_2
# 216 separable_conv_1_normal_right1_2
# 217 separable_conv_1_normal_left2_2
# 218 separable_conv_1_normal_right2_2
# 219 separable_conv_1_normal_left5_2
# 220 separable_conv_1_bn_normal_left1_2
# 221 separable_conv_1_bn_normal_right1_2
# 222 separable_conv_1_bn_normal_left2_2
# 223 separable_conv_1_bn_normal_right2_2
# 224 separable_conv_1_bn_normal_left5_2
# 225 activation_49
# 226 activation_51
# 227 activation_53
# 228 activation_55
# 229 activation_57
# 230 separable_conv_2_normal_left1_2
# 231 separable_conv_2_normal_right1_2
# 232 separable_conv_2_normal_left2_2
# 233 separable_conv_2_normal_right2_2
# 234 separable_conv_2_normal_left5_2
# 235 separable_conv_2_bn_normal_left1_2
# 236 separable_conv_2_bn_normal_right1_2
# 237 separable_conv_2_bn_normal_left2_2
# 238 separable_conv_2_bn_normal_right2_2
# 239 normal_left3_2
# 240 normal_left4_2
# 241 normal_right4_2
# 242 separable_conv_2_bn_normal_left5_2
# 243 normal_add_1_2
# 244 normal_add_2_2
# 245 normal_add_3_2
# 246 normal_add_4_2
# 247 normal_add_5_2
# 248 normal_concat_2
# 249 activation_58
# 250 activation_59
# 251 adjust_conv_projection_3
# 252 normal_conv_1_3
# 253 adjust_bn_3
# 254 normal_bn_1_3
# 255 activation_60
# 256 activation_62
# 257 activation_64
# 258 activation_66
# 259 activation_68
# 260 separable_conv_1_normal_left1_3
# 261 separable_conv_1_normal_right1_3
# 262 separable_conv_1_normal_left2_3
# 263 separable_conv_1_normal_right2_3
# 264 separable_conv_1_normal_left5_3
# 265 separable_conv_1_bn_normal_left1_3
# 266 separable_conv_1_bn_normal_right1_3
# 267 separable_conv_1_bn_normal_left2_3
# 268 separable_conv_1_bn_normal_right2_3
# 269 separable_conv_1_bn_normal_left5_3
# 270 activation_61
# 271 activation_63
# 272 activation_65
# 273 activation_67
# 274 activation_69
# 275 separable_conv_2_normal_left1_3
# 276 separable_conv_2_normal_right1_3
# 277 separable_conv_2_normal_left2_3
# 278 separable_conv_2_normal_right2_3
# 279 separable_conv_2_normal_left5_3
# 280 separable_conv_2_bn_normal_left1_3
# 281 separable_conv_2_bn_normal_right1_3
# 282 separable_conv_2_bn_normal_left2_3
# 283 separable_conv_2_bn_normal_right2_3
# 284 normal_left3_3
# 285 normal_left4_3
# 286 normal_right4_3
# 287 separable_conv_2_bn_normal_left5_3
# 288 normal_add_1_3
# 289 normal_add_2_3
# 290 normal_add_3_3
# 291 normal_add_4_3
# 292 normal_add_5_3
# 293 normal_concat_3
# 294 activation_71
# 295 activation_70
# 296 reduction_conv_1_reduce_4
# 297 adjust_conv_projection_reduce_4
# 298 reduction_bn_1_reduce_4
# 299 adjust_bn_reduce_4
# 300 activation_72
# 301 activation_74
# 302 separable_conv_1_pad_reduction_left1_reduce_4
# 303 separable_conv_1_pad_reduction_right1_reduce_4
# 304 separable_conv_1_reduction_left1_reduce_4
# 305 separable_conv_1_reduction_right1_reduce_4
# 306 separable_conv_1_bn_reduction_left1_reduce_4
# 307 separable_conv_1_bn_reduction_right1_reduce_4
# 308 activation_73
# 309 activation_75
# 310 separable_conv_2_reduction_left1_reduce_4
# 311 separable_conv_2_reduction_right1_reduce_4
# 312 activation_76
# 313 separable_conv_2_bn_reduction_left1_reduce_4
# 314 separable_conv_2_bn_reduction_right1_reduce_4
# 315 separable_conv_1_pad_reduction_right2_reduce_4
# 316 activation_78
# 317 reduction_add_1_reduce_4
# 318 separable_conv_1_reduction_right2_reduce_4
# 319 separable_conv_1_pad_reduction_right3_reduce_4
# 320 activation_80
# 321 separable_conv_1_bn_reduction_right2_reduce_4
# 322 separable_conv_1_reduction_right3_reduce_4
# 323 separable_conv_1_reduction_left4_reduce_4
# 324 activation_77
# 325 separable_conv_1_bn_reduction_right3_reduce_4
# 326 separable_conv_1_bn_reduction_left4_reduce_4
# 327 reduction_pad_1_reduce_4
# 328 separable_conv_2_reduction_right2_reduce_4
# 329 activation_79
# 330 activation_81
# 331 reduction_left2_reduce_4
# 332 separable_conv_2_bn_reduction_right2_reduce_4
# 333 separable_conv_2_reduction_right3_reduce_4
# 334 separable_conv_2_reduction_left4_reduce_4
# 335 adjust_relu_1_5
# 336 reduction_add_2_reduce_4
# 337 reduction_left3_reduce_4
# 338 separable_conv_2_bn_reduction_right3_reduce_4
# 339 reduction_left4_reduce_4
# 340 separable_conv_2_bn_reduction_left4_reduce_4
# 341 reduction_right5_reduce_4
# 342 zero_padding2d_3
# 343 reduction_add3_reduce_4
# 344 add_3
# 345 reduction_add4_reduce_4
# 346 cropping2d_3
# 347 reduction_concat_reduce_4
# 348 adjust_avg_pool_1_5
# 349 adjust_avg_pool_2_5
# 350 adjust_conv_1_5
# 351 adjust_conv_2_5
# 352 activation_82
# 353 concatenate_3
# 354 normal_conv_1_5
# 355 adjust_bn_5
# 356 normal_bn_1_5
# 357 activation_83
# 358 activation_85
# 359 activation_87
# 360 activation_89
# 361 activation_91
# 362 separable_conv_1_normal_left1_5
# 363 separable_conv_1_normal_right1_5
# 364 separable_conv_1_normal_left2_5
# 365 separable_conv_1_normal_right2_5
# 366 separable_conv_1_normal_left5_5
# 367 separable_conv_1_bn_normal_left1_5
# 368 separable_conv_1_bn_normal_right1_5
# 369 separable_conv_1_bn_normal_left2_5
# 370 separable_conv_1_bn_normal_right2_5
# 371 separable_conv_1_bn_normal_left5_5
# 372 activation_84
# 373 activation_86
# 374 activation_88
# 375 activation_90
# 376 activation_92
# 377 separable_conv_2_normal_left1_5
# 378 separable_conv_2_normal_right1_5
# 379 separable_conv_2_normal_left2_5
# 380 separable_conv_2_normal_right2_5
# 381 separable_conv_2_normal_left5_5
# 382 separable_conv_2_bn_normal_left1_5
# 383 separable_conv_2_bn_normal_right1_5
# 384 separable_conv_2_bn_normal_left2_5
# 385 separable_conv_2_bn_normal_right2_5
# 386 normal_left3_5
# 387 normal_left4_5
# 388 normal_right4_5
# 389 separable_conv_2_bn_normal_left5_5
# 390 normal_add_1_5
# 391 normal_add_2_5
# 392 normal_add_3_5
# 393 normal_add_4_5
# 394 normal_add_5_5
# 395 normal_concat_5
# 396 activation_93
# 397 activation_94
# 398 adjust_conv_projection_6
# 399 normal_conv_1_6
# 400 adjust_bn_6
# 401 normal_bn_1_6
# 402 activation_95
# 403 activation_97
# 404 activation_99
# 405 activation_101
# 406 activation_103
# 407 separable_conv_1_normal_left1_6
# 408 separable_conv_1_normal_right1_6
# 409 separable_conv_1_normal_left2_6
# 410 separable_conv_1_normal_right2_6
# 411 separable_conv_1_normal_left5_6
# 412 separable_conv_1_bn_normal_left1_6
# 413 separable_conv_1_bn_normal_right1_6
# 414 separable_conv_1_bn_normal_left2_6
# 415 separable_conv_1_bn_normal_right2_6
# 416 separable_conv_1_bn_normal_left5_6
# 417 activation_96
# 418 activation_98
# 419 activation_100
# 420 activation_102
# 421 activation_104
# 422 separable_conv_2_normal_left1_6
# 423 separable_conv_2_normal_right1_6
# 424 separable_conv_2_normal_left2_6
# 425 separable_conv_2_normal_right2_6
# 426 separable_conv_2_normal_left5_6
# 427 separable_conv_2_bn_normal_left1_6
# 428 separable_conv_2_bn_normal_right1_6
# 429 separable_conv_2_bn_normal_left2_6
# 430 separable_conv_2_bn_normal_right2_6
# 431 normal_left3_6
# 432 normal_left4_6
# 433 normal_right4_6
# 434 separable_conv_2_bn_normal_left5_6
# 435 normal_add_1_6
# 436 normal_add_2_6
# 437 normal_add_3_6
# 438 normal_add_4_6
# 439 normal_add_5_6
# 440 normal_concat_6
# 441 activation_105
# 442 activation_106
# 443 adjust_conv_projection_7
# 444 normal_conv_1_7
# 445 adjust_bn_7
# 446 normal_bn_1_7
# 447 activation_107
# 448 activation_109
# 449 activation_111
# 450 activation_113
# 451 activation_115
# 452 separable_conv_1_normal_left1_7
# 453 separable_conv_1_normal_right1_7
# 454 separable_conv_1_normal_left2_7
# 455 separable_conv_1_normal_right2_7
# 456 separable_conv_1_normal_left5_7
# 457 separable_conv_1_bn_normal_left1_7
# 458 separable_conv_1_bn_normal_right1_7
# 459 separable_conv_1_bn_normal_left2_7
# 460 separable_conv_1_bn_normal_right2_7
# 461 separable_conv_1_bn_normal_left5_7
# 462 activation_108
# 463 activation_110
# 464 activation_112
# 465 activation_114
# 466 activation_116
# 467 separable_conv_2_normal_left1_7
# 468 separable_conv_2_normal_right1_7
# 469 separable_conv_2_normal_left2_7
# 470 separable_conv_2_normal_right2_7
# 471 separable_conv_2_normal_left5_7
# 472 separable_conv_2_bn_normal_left1_7
# 473 separable_conv_2_bn_normal_right1_7
# 474 separable_conv_2_bn_normal_left2_7
# 475 separable_conv_2_bn_normal_right2_7
# 476 normal_left3_7
# 477 normal_left4_7
# 478 normal_right4_7
# 479 separable_conv_2_bn_normal_left5_7
# 480 normal_add_1_7
# 481 normal_add_2_7
# 482 normal_add_3_7
# 483 normal_add_4_7
# 484 normal_add_5_7
# 485 normal_concat_7
# 486 activation_117
# 487 activation_118
# 488 adjust_conv_projection_8
# 489 normal_conv_1_8
# 490 adjust_bn_8
# 491 normal_bn_1_8
# 492 activation_119
# 493 activation_121
# 494 activation_123
# 495 activation_125
# 496 activation_127
# 497 separable_conv_1_normal_left1_8
# 498 separable_conv_1_normal_right1_8
# 499 separable_conv_1_normal_left2_8
# 500 separable_conv_1_normal_right2_8
# 501 separable_conv_1_normal_left5_8
# 502 separable_conv_1_bn_normal_left1_8
# 503 separable_conv_1_bn_normal_right1_8
# 504 separable_conv_1_bn_normal_left2_8
# 505 separable_conv_1_bn_normal_right2_8
# 506 separable_conv_1_bn_normal_left5_8
# 507 activation_120
# 508 activation_122
# 509 activation_124
# 510 activation_126
# 511 activation_128
# 512 separable_conv_2_normal_left1_8
# 513 separable_conv_2_normal_right1_8
# 514 separable_conv_2_normal_left2_8
# 515 separable_conv_2_normal_right2_8
# 516 separable_conv_2_normal_left5_8
# 517 separable_conv_2_bn_normal_left1_8
# 518 separable_conv_2_bn_normal_right1_8
# 519 separable_conv_2_bn_normal_left2_8
# 520 separable_conv_2_bn_normal_right2_8
# 521 normal_left3_8
# 522 normal_left4_8
# 523 normal_right4_8
# 524 separable_conv_2_bn_normal_left5_8
# 525 normal_add_1_8
# 526 normal_add_2_8
# 527 normal_add_3_8
# 528 normal_add_4_8
# 529 normal_add_5_8
# 530 normal_concat_8
# 531 activation_130
# 532 activation_129
# 533 reduction_conv_1_reduce_8
# 534 adjust_conv_projection_reduce_8
# 535 reduction_bn_1_reduce_8
# 536 adjust_bn_reduce_8
# 537 activation_131
# 538 activation_133
# 539 separable_conv_1_pad_reduction_left1_reduce_8
# 540 separable_conv_1_pad_reduction_right1_reduce_8
# 541 separable_conv_1_reduction_left1_reduce_8
# 542 separable_conv_1_reduction_right1_reduce_8
# 543 separable_conv_1_bn_reduction_left1_reduce_8
# 544 separable_conv_1_bn_reduction_right1_reduce_8
# 545 activation_132
# 546 activation_134
# 547 separable_conv_2_reduction_left1_reduce_8
# 548 separable_conv_2_reduction_right1_reduce_8
# 549 activation_135
# 550 separable_conv_2_bn_reduction_left1_reduce_8
# 551 separable_conv_2_bn_reduction_right1_reduce_8
# 552 separable_conv_1_pad_reduction_right2_reduce_8
# 553 activation_137
# 554 reduction_add_1_reduce_8
# 555 separable_conv_1_reduction_right2_reduce_8
# 556 separable_conv_1_pad_reduction_right3_reduce_8
# 557 activation_139
# 558 separable_conv_1_bn_reduction_right2_reduce_8
# 559 separable_conv_1_reduction_right3_reduce_8
# 560 separable_conv_1_reduction_left4_reduce_8
# 561 activation_136
# 562 separable_conv_1_bn_reduction_right3_reduce_8
# 563 separable_conv_1_bn_reduction_left4_reduce_8
# 564 reduction_pad_1_reduce_8
# 565 separable_conv_2_reduction_right2_reduce_8
# 566 activation_138
# 567 activation_140
# 568 reduction_left2_reduce_8
# 569 separable_conv_2_bn_reduction_right2_reduce_8
# 570 separable_conv_2_reduction_right3_reduce_8
# 571 separable_conv_2_reduction_left4_reduce_8
# 572 adjust_relu_1_9
# 573 reduction_add_2_reduce_8
# 574 reduction_left3_reduce_8
# 575 separable_conv_2_bn_reduction_right3_reduce_8
# 576 reduction_left4_reduce_8
# 577 separable_conv_2_bn_reduction_left4_reduce_8
# 578 reduction_right5_reduce_8
# 579 zero_padding2d_4
# 580 reduction_add3_reduce_8
# 581 add_4
# 582 reduction_add4_reduce_8
# 583 cropping2d_4
# 584 reduction_concat_reduce_8
# 585 adjust_avg_pool_1_9
# 586 adjust_avg_pool_2_9
# 587 adjust_conv_1_9
# 588 adjust_conv_2_9
# 589 activation_141
# 590 concatenate_4
# 591 normal_conv_1_9
# 592 adjust_bn_9
# 593 normal_bn_1_9
# 594 activation_142
# 595 activation_144
# 596 activation_146
# 597 activation_148
# 598 activation_150
# 599 separable_conv_1_normal_left1_9
# 600 separable_conv_1_normal_right1_9
# 601 separable_conv_1_normal_left2_9
# 602 separable_conv_1_normal_right2_9
# 603 separable_conv_1_normal_left5_9
# 604 separable_conv_1_bn_normal_left1_9
# 605 separable_conv_1_bn_normal_right1_9
# 606 separable_conv_1_bn_normal_left2_9
# 607 separable_conv_1_bn_normal_right2_9
# 608 separable_conv_1_bn_normal_left5_9
# 609 activation_143
# 610 activation_145
# 611 activation_147
# 612 activation_149
# 613 activation_151
# 614 separable_conv_2_normal_left1_9
# 615 separable_conv_2_normal_right1_9
# 616 separable_conv_2_normal_left2_9
# 617 separable_conv_2_normal_right2_9
# 618 separable_conv_2_normal_left5_9
# 619 separable_conv_2_bn_normal_left1_9
# 620 separable_conv_2_bn_normal_right1_9
# 621 separable_conv_2_bn_normal_left2_9
# 622 separable_conv_2_bn_normal_right2_9
# 623 normal_left3_9
# 624 normal_left4_9
# 625 normal_right4_9
# 626 separable_conv_2_bn_normal_left5_9
# 627 normal_add_1_9
# 628 normal_add_2_9
# 629 normal_add_3_9
# 630 normal_add_4_9
# 631 normal_add_5_9
# 632 normal_concat_9
# 633 activation_152
# 634 activation_153
# 635 adjust_conv_projection_10
# 636 normal_conv_1_10
# 637 adjust_bn_10
# 638 normal_bn_1_10
# 639 activation_154
# 640 activation_156
# 641 activation_158
# 642 activation_160
# 643 activation_162
# 644 separable_conv_1_normal_left1_10
# 645 separable_conv_1_normal_right1_10
# 646 separable_conv_1_normal_left2_10
# 647 separable_conv_1_normal_right2_10
# 648 separable_conv_1_normal_left5_10
# 649 separable_conv_1_bn_normal_left1_10
# 650 separable_conv_1_bn_normal_right1_10
# 651 separable_conv_1_bn_normal_left2_10
# 652 separable_conv_1_bn_normal_right2_10
# 653 separable_conv_1_bn_normal_left5_10
# 654 activation_155
# 655 activation_157
# 656 activation_159
# 657 activation_161
# 658 activation_163
# 659 separable_conv_2_normal_left1_10
# 660 separable_conv_2_normal_right1_10
# 661 separable_conv_2_normal_left2_10
# 662 separable_conv_2_normal_right2_10
# 663 separable_conv_2_normal_left5_10
# 664 separable_conv_2_bn_normal_left1_10
# 665 separable_conv_2_bn_normal_right1_10
# 666 separable_conv_2_bn_normal_left2_10
# 667 separable_conv_2_bn_normal_right2_10
# 668 normal_left3_10
# 669 normal_left4_10
# 670 normal_right4_10
# 671 separable_conv_2_bn_normal_left5_10
# 672 normal_add_1_10
# 673 normal_add_2_10
# 674 normal_add_3_10
# 675 normal_add_4_10
# 676 normal_add_5_10
# 677 normal_concat_10
# 678 activation_164
# 679 activation_165
# 680 adjust_conv_projection_11
# 681 normal_conv_1_11
# 682 adjust_bn_11
# 683 normal_bn_1_11
# 684 activation_166
# 685 activation_168
# 686 activation_170
# 687 activation_172
# 688 activation_174
# 689 separable_conv_1_normal_left1_11
# 690 separable_conv_1_normal_right1_11
# 691 separable_conv_1_normal_left2_11
# 692 separable_conv_1_normal_right2_11
# 693 separable_conv_1_normal_left5_11
# 694 separable_conv_1_bn_normal_left1_11
# 695 separable_conv_1_bn_normal_right1_11
# 696 separable_conv_1_bn_normal_left2_11
# 697 separable_conv_1_bn_normal_right2_11
# 698 separable_conv_1_bn_normal_left5_11
# 699 activation_167
# 700 activation_169
# 701 activation_171
# 702 activation_173
# 703 activation_175
# 704 separable_conv_2_normal_left1_11
# 705 separable_conv_2_normal_right1_11
# 706 separable_conv_2_normal_left2_11
# 707 separable_conv_2_normal_right2_11
# 708 separable_conv_2_normal_left5_11
# 709 separable_conv_2_bn_normal_left1_11
# 710 separable_conv_2_bn_normal_right1_11
# 711 separable_conv_2_bn_normal_left2_11
# 712 separable_conv_2_bn_normal_right2_11
# 713 normal_left3_11
# 714 normal_left4_11
# 715 normal_right4_11
# 716 separable_conv_2_bn_normal_left5_11
# 717 normal_add_1_11
# 718 normal_add_2_11
# 719 normal_add_3_11
# 720 normal_add_4_11
# 721 normal_add_5_11
# 722 normal_concat_11
# 723 activation_176
# 724 activation_177
# 725 adjust_conv_projection_12
# 726 normal_conv_1_12
# 727 adjust_bn_12
# 728 normal_bn_1_12
# 729 activation_178
# 730 activation_180
# 731 activation_182
# 732 activation_184
# 733 activation_186
# 734 separable_conv_1_normal_left1_12
# 735 separable_conv_1_normal_right1_12
# 736 separable_conv_1_normal_left2_12
# 737 separable_conv_1_normal_right2_12
# 738 separable_conv_1_normal_left5_12
# 739 separable_conv_1_bn_normal_left1_12
# 740 separable_conv_1_bn_normal_right1_12
# 741 separable_conv_1_bn_normal_left2_12
# 742 separable_conv_1_bn_normal_right2_12
# 743 separable_conv_1_bn_normal_left5_12
# 744 activation_179
# 745 activation_181
# 746 activation_183
# 747 activation_185
# 748 activation_187
# 749 separable_conv_2_normal_left1_12
# 750 separable_conv_2_normal_right1_12
# 751 separable_conv_2_normal_left2_12
# 752 separable_conv_2_normal_right2_12
# 753 separable_conv_2_normal_left5_12
# 754 separable_conv_2_bn_normal_left1_12
# 755 separable_conv_2_bn_normal_right1_12
# 756 separable_conv_2_bn_normal_left2_12
# 757 separable_conv_2_bn_normal_right2_12
# 758 normal_left3_12
# 759 normal_left4_12
# 760 normal_right4_12
# 761 separable_conv_2_bn_normal_left5_12
# 762 normal_add_1_12
# 763 normal_add_2_12
# 764 normal_add_3_12
# 765 normal_add_4_12
# 766 normal_add_5_12
# 767 normal_concat_12
# 768 activation_188
# 769 global_average_pooling2d_1
# 770 predictions
